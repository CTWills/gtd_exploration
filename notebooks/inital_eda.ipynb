# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("../data/gtd_jan_june_21.xlsx", index_col=0)

# %%
len(data)
# Out:
# 4960

# %%
countries = data["country_txt"].value_counts(True) * 100

# %%
countries["United States"]
# Out:
# 0.5241935483870969

# %%
for column in data.columns:
    print(column)
# Out:
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %%
data.sample()
# Out:
#               iyear  imonth  iday approxdate  extended resolution  country  \
# eventid
# 202101070002   2021       1     7        NaN         0        NaT        4
#
#               country_txt  region  region_txt  ... addnotes  \
# eventid                                        ...
# 202101070002  Afghanistan       6  South Asia  ...      NaN
#
#                                                          scite1  scite2  \
# eventid
# 202101070002  "Afghan War Casualty Report: January 2021," NY...     NaN
#
#               scite3                  dbsource  INT_LOG INT_IDEO INT_MISC  \
# eventid
# 202101070002     NaN  START Primary Collection        0        0        0
#
#               INT_ANY  related
# eventid
# 202101070002        0      NaN
#
# [1 rows x 134 columns]

# %%
data.shape
# Out:
# (4960, 134)

# %%
data
# Out:
#               iyear  imonth  iday  approxdate  extended resolution  country  \
# eventid
# 202101010004   2021       1     1         NaN         0        NaT       60
# 202101010005   2021       1     1  01/01/2021         0        NaT       92
# 202101010006   2021       1     1         NaN         0        NaT      228
# 202101010009   2021       1     1         NaN         0        NaT        4
# 202101010024   2021       1     2         NaN         0        NaT      182
# ...             ...     ...   ...         ...       ...        ...      ...
# 202106300023   2021       6    30         NaN         0        NaT        4
# 202106300029   2021       6    30  06/30/2021         0        NaT      138
# 202106300030   2021       6    30         NaN         1 2021-07-08      147
# 202106300038   2021       6    30         NaN         0        NaT       45
# 202107020037   2021       6    30         NaN         0        NaT      138
#
# ...

# %%
bools = data.dtypes != "object"
data.columns[bools]
# Out:
# Index(['iyear', 'imonth', 'iday', 'extended', 'resolution', 'country',
#        'region', 'latitude', 'longitude', 'specificity', 'vicinity', 'crit1',
#        'crit2', 'crit3', 'doubtterr', 'alternative', 'multiple', 'success',
#        'suicide', 'attacktype1', 'attacktype2', 'attacktype3', 'targtype1',
#        'targsubtype1', 'natlty1', 'targtype2', 'targsubtype2', 'natlty2',
#        'targtype3', 'targsubtype3', 'natlty3', 'gsubname3', 'guncertain1',
#        'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap',
#        'claimed', 'claimmode', 'claim2', 'claimmode2', 'claim3', 'claimmode3',
#        'compclaim', 'weaptype1', 'weapsubtype1', 'weaptype2', 'weapsubtype2',
#        'weaptype3', 'weapsubtype3', 'weaptype4', 'weaptype4_txt',
#        'weapsubtype4', 'weapsubtype4_txt', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent', 'propvalue',
# ...

# %%
test = data["nperps"] > 0
# Out:
# nperps
# False    4400
# True      560
# Name: count, dtype: int64

# %%
data[data["suicide"] != 0]["suicide"]
# Out:
# eventid
# 202101020009    1
# 202101070005    1
# 202101080007    1
# 202101150011    1
# 202101210004    1
#                ..
# 202106180017    1
# 202106210012    1
# 202106270014    1
# 202106270016    1
# 202106300004    1
# Name: suicide, Length: 79, dtype: int64
